# %% [markdown]
# ## Slicing and combining your data
# * Manipulate and extract pieces of our data
# * Combine different dataframes together

# %%
# Make sure pandas is loaded
import pandas as pd

# Read in the survey CSV
surveys_df = pd.read_csv('data/surveys.csv')

# %%
# selecting specific columns
surveys_species = surveys_df['species_id']
surveys_species = surveys_df.species_id

# %%
#selecting multiple columns
surveys_subset = surveys_df[['species_id', 'plot_id']]

# %%
#selecting rows [from:up-to-not-including]
surveys_df[0:4] #select rows [0,1,2,3]
surveys_df[:6] #select rows [0,1,2,3,4,5]
surveys_df[-5:] #select the last 5 rows
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
surveys_df2 = surveys_df.copy()

# %%
surveys_df2
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN
#
# [35549 rows x 9 columns]

# %%
surveys_df.iloc[0:3, 1:4]
# Out:
#    month  day  year
# 0      7   16  1977
# 1      7   16  1977
# 2      7   16  1977

# %%
surveys_df.loc[0:5, ['plot_id', 'species_id']]
# Out:
#    plot_id species_id
# 0        2         NL
# 1        3         NL
# 2        2         DM
# 3        7         DM
# 4        3         DM
# 5        1         PF

# %%
surveys_df.iloc[0:4, 1:4]
# Out:
#    month  day  year
# 0      7   16  1977
# 1      7   16  1977
# 2      7   16  1977
# 3      7   16  1977

# %%
surveys_df.loc[0:4, 1:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 surveys_df.loc[0:4, 1:4]
#
# File /mnt/miniconda/envs/ood/lib/python3.10/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File /mnt/miniconda/envs/ood/lib/python3.10/site-packages/pandas/core/indexing.py:1256, in _LocIndexer._getitem_tuple(self, tup)
#    1253 if self._multi_take_opportunity(tup):
#    1254     return self._multi_take(tup)
# -> 1256 return self._getitem_tuple_same_dim(tup)
#
# File /mnt/miniconda/envs/ood/lib/python3.10/site-packages/pandas/core/indexing.py:924, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     921 if com.is_null_slice(key):
#     922     continue
# --> 924 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     925 # We should never have retval.ndim < self.ndim, as that should
#     926 #  be handled by the _getitem_lowerdim call above.
#     927 assert retval.ndim == self.ndim
#
# File /mnt/miniconda/envs/ood/lib/python3.10/site-packages/pandas/core/indexing.py:1290, in _LocIndexer._getitem_axis(self, key, axis)
#    1288 if isinstance(key, slice):
#    1289     self._validate_key(key, axis)
# -> 1290     return self._get_slice_axis(key, axis=axis)
#    1291 elif com.is_bool_indexer(key):
#    1292     return self._getbool_axis(key, axis=axis)
#
# File /mnt/miniconda/envs/ood/lib/python3.10/site-packages/pandas/core/indexing.py:1324, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1321     return obj.copy(deep=False)
#    1323 labels = obj._get_axis(axis)
# -> 1324 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1326 if isinstance(indexer, slice):
#    1327     return self.obj._slice(indexer, axis=axis)
#
# File /mnt/miniconda/envs/ood/lib/python3.10/site-packages/pandas/core/indexes/base.py:6600, in Index.slice_indexer(self, start, end, step, kind)
#    6557 """
#    6558 Compute the slice indexer for input labels and step.
#    6559
#    (...)
#    6596 slice(1, 3, None)
#    6597 """
#    6598 self._deprecated_arg(kind, "kind", "slice_indexer")
# -> 6600 start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6602 # return a slice
#    6603 if not is_scalar(start_slice):
#
# File /mnt/miniconda/envs/ood/lib/python3.10/site-packages/pandas/core/indexes/base.py:6808, in Index.slice_locs(self, start, end, step, kind)
#    6806 start_slice = None
#    6807 if start is not None:
# -> 6808     start_slice = self.get_slice_bound(start, "left")
#    6809 if start_slice is None:
#    6810     start_slice = 0
#
# File /mnt/miniconda/envs/ood/lib/python3.10/site-packages/pandas/core/indexes/base.py:6717, in Index.get_slice_bound(self, label, side, kind)
#    6713 original_label = label
#    6715 # For datetime indices label may be a string that has to be converted
#    6716 # to datetime boundary according to its resolution.
# -> 6717 label = self._maybe_cast_slice_bound(label, side)
#    6719 # we need to look up the label
#    6720 try:
#
# File /mnt/miniconda/envs/ood/lib/python3.10/site-packages/pandas/core/indexes/base.py:6664, in Index._maybe_cast_slice_bound(self, label, side, kind)
#    6659 # We are a plain index here (sub-class override this method if they
#    6660 # wish to have special treatment for floats/ints, e.g. Float64Index and
#    6661 # datetimelike Indexes
#    6662 # reject them, if index does not contain label
#    6663 if (is_float(label) or is_integer(label)) and label not in self:
# -> 6664     raise self._invalid_indexer("slice", label)
#    6666 return label
#
# TypeError: cannot do slice indexing on Index with these indexers [1] of type int

# %% [markdown]
# ## Subsetting data using criteria

# %%
surveys_df[(surveys_df["species_id"] == "DM") & (surveys_df.year == 2002)]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 33320      33321      1   12  2002        1         DM   M             38.0
# 33328      33329      1   12  2002        2         DM   M             37.0
# 33335      33336      1   12  2002        2         DM   F             35.0
# 33343      33344      1   12  2002       12         DM   M             36.0
# 33346      33347      1   12  2002       12         DM   F             37.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 35532      35533     12   31  2002       14         DM   F             36.0
# 35533      35534     12   31  2002       14         DM   M             37.0
# 35534      35535     12   31  2002       14         DM   M             37.0
# 35535      35536     12   31  2002       14         DM   F             35.0
# 35536      35537     12   31  2002       14         DM   F             36.0
#
#        weight
# 33320    44.0
# 33328    47.0
# 33335    45.0
# 33343    40.0
# 33346    45.0
# ...       ...
# 35532    48.0
# 35533    56.0
# 35534    53.0
# 35535    42.0
# 35536    46.0
#
# [309 rows x 9 columns]

# %%
surveys_df[(surveys_df["weight"] <= 8) & (surveys_df.year >= 2002)]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 33396      33397      2    9  2002        1         RO   M             17.0
# 33404      33405      2    9  2002        2         RM   M             19.0
# 33428      33429      2    9  2002        3         PF   M             15.0
# 33534      33535      2   10  2002       13         PF   F             15.0
# 33550      33551      2   10  2002       15         RM   F             17.0
# 33560      33561      2   10  2002       10         RM   F             17.0
# 33564      33565      2   10  2002       10         RO   F             16.0
# 33646      33647      3   14  2002        3         PF   M              9.0
# 33653      33654      3   14  2002        4         PF   M             17.0
# 33656      33657      3   14  2002        4         PF   F             16.0
# 33716      33717      3   14  2002       13         PF   M             15.0
# 33729      33730      3   14  2002       15         RM   F             17.0
# 33868      33869      4   17  2002        4         PF   F             15.0
# 33869      33870      4   17  2002        4         PF   M             15.0
# 34070      34071      5   16  2002        4         PF   M             15.0
# 34279      34280      6   15  2002       23         RM   M             16.0
# 34312      34313      6   16  2002        6         PP   M             21.0
# 34402      34403      6   16  2002       16         PF   F             16.0
# 34527      34528      7   13  2002       24         RM   M             15.0
# 34557      34558      7   14  2002        4         PF   F             15.0
# 34662      34663      7   14  2002       16         RM   M             14.0
# 35100      35101     11   10  2002        9         PF   M             14.0
# 35171      35172     11   10  2002       14         PF   F             15.0
# 35300      35301     12    8  2002        4         PF   M             13.0
# 35307      35308     12    8  2002        6         PF   F             16.0
# 35505      35506     12   31  2002        6         PF   M             13.0
#
#        weight
# 33396     8.0
# 33404     8.0
# 33428     8.0
# 33534     7.0
# 33550     7.0
# 33560     8.0
# 33564     8.0
# 33646     8.0
# 33653     8.0
# 33656     8.0
# 33716     7.0
# 33729     7.0
# 33868     8.0
# 33869     7.0
# 34070     7.0
# 34279     7.0
# 34312     8.0
# 34402     5.0
# 34527     7.0
# 34557     7.0
# 34662     7.0
# 35100     7.0
# 35171     7.0
# 35300     6.0
# 35307     6.0
# 35505     8.0

# %%
surveys_head = surveys_df.head(5)
surveys_tail = surveys_df.tail(5)

# %%
vertical_stack = pd.concat([surveys_head, surveys_tail], axis=0)

# %%
vertical_stack
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN
